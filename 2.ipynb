# %%
from common import *

for file in [["level2/POL0001_balucki_bialy-murzyn.xml", "Bialy murzyn (Bialucki)"], ["level2/POL0003_balucki_przebudzeni.xml", "Przebudzeni (Bialucki)"],
             ["level2/POL0002_balucki_pan-burmistrz.xml", "Pan burmistrz (Bialucki)"]]:
    words = get_words(file[0])
    words = [w.attrib['lemma'] for w in words]
    zipf(words)
    plt.title(file[1] + " - prawo Zipfa")
    plt.show()
    heaps_analysis(words)
    plt.title(file[1] + " - prawo Heapsa-Herdana")
    plt.show()
