# %%
from analisis import *

for file in ["level2/POL0001_balucki_bialy-murzyn.xml", "level2/POL0002_balucki_pan-burmistrz.xml", "level2/POL0003_balucki_przebudzeni.xml"]:
    words = get_words(file)
    words = [w.attrib['lemma'] for w in words]
    zipf_analysis(words)
    plt.title(file + " zipf")
    plt.show()
    heaps_analysis(words)
    plt.title(file + " heaps")
    plt.show()
