# %%
from analisis import *

for file in ["level2/POL0001_balucki_bialy-murzyn.xml", "level2/POL0013_dmochowska_dwor-w-haliniszkach.xml", "level2/POL0031_kaczkowski_grob-nieczui.xml"]:
    words = get_words(file)
    words = [w.text for w in words]
    zipf_analysis(words)
    plt.title(file + " zipf")
    plt.show()
    heaps_analysis(words)
    plt.title(file + " heaps")
    plt.show()
