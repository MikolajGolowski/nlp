# %%
from common import *

for file in [["level2/POL0001_balucki_bialy-murzyn.xml", "Bialy murzyn (Bialucki)"], ["level2/POL0022_dygasinski_as.xml", "As (Dygasiński)"],
             ["level2/POL0049_mniszek_gehenna.xml", "Gehenna (Mniszek)"]]:
    words = get_words(file[0])
    words = [w.text for w in words]
    zipf(words)
    plt.title(file[1] + " - prawo Zipfa")
    plt.show()
    heaps_analysis(words)
    plt.title(file[1] + " - prawo Heapsa-Herdana")
    plt.show()
