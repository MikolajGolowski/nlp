# %%
from analisis import *

for file in ["level2/POL0001_balucki_bialy-murzyn.xml", "fra-lvl2/FRA01202_Feval.xml", "eng-lvl2/ENG18570_Bronte.xml"]:
    words = get_words(file)
    words = [w.text for w in words]
    zipf_analysis(words)
    plt.title(file + " zipf")
    plt.show()
    heaps_analysis(words)
    plt.title(file + " heaps")
    plt.show()
