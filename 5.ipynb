# %%
from common import *
for file in [["level2/POL0001_balucki_bialy-murzyn.xml", "Bialucki - POL"], ["fra-lvl2/FRA01202_Feval.xml", "Feval - FRA"],
             ["eng-lvl2/ENG18570_Bronte.xml", "Bronte - ENG"]]:
    words = get_words(file[0])
    words = [w.text for w in words]
    zipf(words)
    plt.title(file[1] + " - prawo Zipfa")
    plt.show()
    heaps_analysis(words)
    plt.title(file[1] + " - prawo Heapsa-Herdana")
    plt.show()
